# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(np.argmax(a))
# Out:
# 4

# %%
print(np.argmin(a))
# Out:
# 0

# %%
a=np.array([10,82,23,7,5])
print(np.argmax(a))
# Out:
# 1

# %%
print(np.argmin(a))
# Out:
# 4

# %%
print(np.where(a>3))
# Out:
# (array([0, 1, 2, 3, 4]),)

# %%
print(np.cumsum(a))
# Out:
# [ 10  92 115 122 127]

# %%
r=np.random.randint(1,20,20)
print(r)
# Out:
# [11  7  9 10 19  6 10  5  8 13  4  2  4 16  5  2 12  8 13 15]

# %%
r=np.random.randint(23,30,15)
print(r)
# Out:
# [26 23 28 26 23 23 28 29 25 25 25 28 26 26 26]

# %%
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
print(np.corrcoef(a,b))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
a=np.array([1,2,3,4,5])
b=np.array([5,4,3,2,1])
print(np.corrcoef(a,b))
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
a=np.array([1,3,2,1,10,9])
b=np.array([5,10,12,9,3,2])
print(np.corrcoef(a,b))
# Out:
# [[ 1.         -0.74223004]
#  [-0.74223004  1.        ]]

# %%
a=np.array([1,2,3,4,5])
np.save("ps.npy",a)
print(np.load("ps.npy"))
# Out:
# [1 2 3 4 5]

# %%
a=np.array([1,2,3,4,5])
print(a[2:4])
# Out:
# [3 4]

# %%
print(a[2:])
# Out:
# [3 4 5]

# %%
print(a[:3])
# Out:
# [1 2 3]

# %%
print(a[:-3])
# Out:
# [1 2]

# %%
print(a[-3:])
# Out:
# [3 4 5]

# %%
Arr=np.array([[1,2,3,4],[3,4,5,6],[7,8,9,2]])
print(Arr[0:1,1:3])
# Out:
# [[2 3]]

# %%
print(Arr[:,1:2])
# Out:
# [[2]
#  [4]
#  [8]]

# %%
print(Arr[:,::2])
# Out:
# [[1 3]
#  [3 5]
#  [7 9]]

# %%
print(Arr[:,::])
# Out:
# [[1 2 3 4]
#  [3 4 5 6]
#  [7 8 9 2]]
